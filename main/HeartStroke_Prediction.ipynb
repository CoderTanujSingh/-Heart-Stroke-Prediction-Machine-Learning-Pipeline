# %%
import pickle
import numpy as np
import pandas as pd

# %%
pipe = pickle.load(open('model/pipe.pkl', 'rb'))

# %% [markdown]
# # We will assume user inputs

# %%
cols = ['Gender','age','education','currentSmoker','cigsPerDay','BPMeds',
        'prevalentStroke','prevalentHyp','diabetes','totChol','sysBP',
        'diaBP','BMI','heartRate','glucose','HeartStroke']

# %%
test_input2 = pd.DataFrame([[
    'male',62, 'graduate',1,18,0,'no',0,0,235.0,150.0,95.0,30.25,63.0,70.0,
]],columns=cols)

# %%
test_input2
# Out:
#   Gender  age education  currentSmoker  cigsPerDay  BPMeds prevalentStroke  \
# 0   male   62  graduate              1          18       0              no
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose
# 0             0         0    235.0  150.0   95.0  30.25       63.0     70.0

# %%
pipe.predict(test_input2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 pipe.predict(test_input2)
#
# File ~\anaconda3\Lib\site-packages\sklearn\pipeline.py:787, in Pipeline.predict(self, X, **params)
#     785 if not _routing_enabled():
#     786     for _, name, transform in self._iter(with_final=False):
# --> 787         Xt = transform.transform(Xt)
#     788     return self.steps[-1][1].predict(Xt, **params)
#     790 # metadata routing enabled
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
# ...
